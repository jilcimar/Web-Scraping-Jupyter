# %%
#Imports
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import pandas

# %%
#Fazendo as requisições para o download das páginas
#Criando função para receber uma URL e verificar se tem algum 
#Conteúdo do tipo HTML/texto 
def get_url(url):
    try:
        with closing(get(url,stream=True)) as resp:
            if response_true(resp):
                return resp.content
            else:
                return None
    except RequestException as e:
        log_error("Erro de solicitação ".format(url,str(e)))
        return None
    
#Função para imprimir os erros 
def log_error(e):
    print(e)
    
#Função que retorna true caso seja HTML
def response_true(resp):
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code==200
           and content_type is not None
           and content_type.find('html')>-1)
#URL do Cinemark (Natal)
page = get_url("https://www.cinemark.com.br/natal/cinemas?cinema=681")

# %%
#Tratando o HTML bruto#Tratan 
html = BeautifulSoup(page, 'html.parser')

#Pegando a div com as informações dos filmes
movies = html.findAll("div", {"class": "theater"})

title_movie = []
horary = []

for movie in movies:
    title_movie.append(movie.find("h3", {"class":"title"}).text)
    horary.append(movie.find("ul", {"class":"times-options"}).text.replace('\n',''))
                  
                  
#Ordenando por horário
df = pandas.DataFrame({
    "Title": title_movie,
    "Horary": sorted(horary)
})
                  
df
# Out:
#              Horary                                        Title
# 0             00:01                        Exorcismos e Demônios
# 1             12:10      Nada a Perder - Contra tudo. Por Todos.
# 2             12:10                    Paulo, Apóstolo de Cristo
# 3             12:50                                 Pedro Coelho
# 4             12:50                   Rampage – Destruição Total
# 5             12:50                          Um Lugar Silencioso
# 6             12:50                           Verdade ou Desafio
# 7             12:50                  Vingadores: Guerra Infinita
# 8        13:0015:25                        Exorcismos e Demônios
# 9        13:0015:25      Nada a Perder - Contra tudo. Por Todos.
# 10       13:0515:40                    Paulo, Apóstolo de Cristo
# 11       13:0515:40                                 Pedro Coelho
# 12       13:0515:40                   Rampage – Destruição Total
# 13       13:0515:40                          Um Lugar Silencioso
# 14       13:0515:40                           Verdade ou Desafio
# 15            13:10                  Vingadores: Guerra Infinita
# 16            13:10                        Exorcismos e Demônios
# 17       13:2016:30      Nada a Perder - Contra tudo. Por Todos.
# 18       13:2016:30                                Os Farofeiros
# 19       13:3016:00                    Paulo, Apóstolo de Cristo
# 20       13:3016:00                                 Pedro Coelho
# 21       13:3016:00                                Querida Mamãe
# 22       13:3016:00                   Rampage – Destruição Total
# 23       13:3016:00                          Um Lugar Silencioso
# 24       13:3016:00                           Verdade ou Desafio
# 25       13:3016:00                  Vingadores: Guerra Infinita
# 26       14:0016:30                        Exorcismos e Demônios
# 27       14:0016:30      Nada a Perder - Contra tudo. Por Todos.
# 28       14:0016:30                                Os Farofeiros
# 29            14:10                    Paulo, Apóstolo de Cristo
# ..              ...                                          ...
# 41  15:1018:1021:10                                Querida Mamãe
# 42  15:1018:1021:10                   Rampage – Destruição Total
# 43            16:20                          Um Lugar Silencioso
# 44            16:20                           Verdade ou Desafio
# 45            16:20                  Vingadores: Guerra Infinita
# 46            16:20                                   Deadpool 2
# 47            16:20                                   Deadpool 2
# 48       17:3020:20      Nada a Perder - Contra tudo. Por Todos.
# 49       17:3020:20                                   Deadpool 2
# 50       17:3020:20      Nada a Perder - Contra tudo. Por Todos.
# 51       17:3020:20                                   Deadpool 2
# 52       17:3020:20      Nada a Perder - Contra tudo. Por Todos.
# 53       17:5021:00                                   Deadpool 2
# 54       17:5021:00      Nada a Perder - Contra tudo. Por Todos.
# 55       17:5021:00                                   Deadpool 2
# 56            18:10      Nada a Perder - Contra tudo. Por Todos.
# 57            18:10  Animé Night - Attack On Titan: Fim do Mundo
# 58            18:10                                   Deadpool 2
# 59            18:10      Nada a Perder - Contra tudo. Por Todos.
# 60            18:10                                   Deadpool 2
# 61            18:10             Han Solo: Uma História Star Wars
# 62            18:10      Nada a Perder - Contra tudo. Por Todos.
# 63            19:00             Han Solo: Uma História Star Wars
# 64            19:00             Han Solo: Uma História Star Wars
# 65            19:00          Final da UEFA Champions League 2018
# 66            19:30             Han Solo: Uma História Star Wars
# 67       20:0022:30             Han Solo: Uma História Star Wars
# 68            21:20             Han Solo: Uma História Star Wars
# 69            21:20             Han Solo: Uma História Star Wars
# 70            21:20             Han Solo: Uma História Star Wars
#
# [71 rows x 2 columns]
