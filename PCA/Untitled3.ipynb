# %%
import numpy as np 
import random 
import matplotlib.pyplot as plt


b0 = 0.1 
b1 = 0.2
b2 = 0.1


xi = np.random.normal(0,1,100)
er = np.random.normal(0,1,100)

y = b0 + b1*xi+b2*(xi*xi)+er

p = np.polyfit(xi,y,0, full = True)

plt.plot(xi, y , 30)
